# %%
from keras.datasets import mnist
 
data=mnist.load_data()

# %%
((X_train,y_train ),(X_test,y_test))=data

# %%
X_train=X_train. reshape ((X_train. shape[0],28*28)).astype('float32')
X_test=X_test. reshape ((X_test. shape[0],28*28)).astype('float32')

# %%
X_train = X_train/255
X_test = X_test/255

# %%
from keras.utils import np_utils
 
print(y_test. shape)
 
y_train =np_utils. to_categorical (y_train)
y_test =np_utils. to_categorical (y_test)
 
num_classes=y_test. shape[1]
print(y_test. shape)
# Out:
# (10000,)
# (10000, 10)

# %%
model = Sequential()
model.add(Dense(32,input_dim = 28*28,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
from keras. models import Sequential
from keras.layers import Dense

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=10,batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7717 - accuracy: 0.7804
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2055 - accuracy: 0.9408
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1526 - accuracy: 0.9545
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1298 - accuracy: 0.9618
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1088 - accuracy: 0.9674
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0912 - accuracy: 0.9724
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0866 - accuracy: 0.9739
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0747 - accuracy: 0.9772
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0758 - accuracy: 0.9755
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0611 - accuracy: 0.9810

# %%
scores = model.evaluate(X_test,y_test)
print (scores)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0993 - accuracy: 0.9706
# [0.09928502142429352, 0.9706000089645386]
